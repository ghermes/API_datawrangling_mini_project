# %%
import pandas as pd
import numpy as np
import json

# %%
ca_data = pd.read_csv(r'C:\Users\straw\OneDrive\Desktop\SpringBoard Projects\2nd Capstone - CA Crime Rate\California_City_Crime_Rates.csv', encoding='latin-1')
print(ca_data)
# Out:
#     table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0    Annual Estimates of the Resident Population fo...
# 1                                      Geographic Area
# 2                                                  NaN
# 3                            Adelanto city, California
# 4                        Agoura Hills city, California
# ..                                                 ...
# 485  Note: The estimates are based on the 2010 Cens...
# 486                                Suggested Citation:
# 487  Annual Estimates of the Resident Population fo...
# 488    Source: U.S. Census Bureau, Population Division
# 489                             Release Date: May 2020
#
#     Unnamed: 1      Unnamed: 2                          Unnamed: 3 Unnamed: 4  \
# 0          NaN             NaN                                 NaN        NaN
# 1     1-Apr-10             NaN  Population Estimate (as of July 1)        NaN
# ...

# %%
ca_data = ca_data.to_json()
print(ca_data)
# Out:
# {"table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)":{"0":"Annual Estimates of the Resident Population for Incorporated Places in California: April 1, 2010 to July 1, 2019","1":"Geographic Area","2":null,"3":"Adelanto city, California","4":"Agoura Hills city, California","5":"Alameda city, California","6":"Albany city, California","7":"Alhambra city, California","8":"Aliso Viejo city, California","9":"Alturas city, California","10":"Amador City city, California","11":"American Canyon city, California","12":"Anaheim city, California","13":"Anderson city, California","14":"Angels city, California","15":"Antioch city, California","16":"Apple Valley town, California","17":"Arcadia city, California","18":"Arcata city, California","19":"Arroyo Grande city, California","20":"Artesia city, California","21":"Arvin city, California","22":"Atascadero city, California","23":"Atherton town, California","24":"Atwater city, California","25":
# ...

# %%
type(ca_data)
# Out:
# str

# %%
ca_data = json.loads(ca_data)
type(ca_data)
# Out:
# dict

# %%
print(ca_data.keys())
# Out:
# dict_keys(['table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'])

# %%
# Rename all the keys
ca_data['Cities'] = ca_data.pop('table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)')
print(ca_data['Cities'])
# Out:
# {'0': 'Annual Estimates of the Resident Population for Incorporated Places in California: April 1, 2010 to July 1, 2019', '1': 'Geographic Area', '2': None, '3': 'Adelanto city, California', '4': 'Agoura Hills city, California', '5': 'Alameda city, California', '6': 'Albany city, California', '7': 'Alhambra city, California', '8': 'Aliso Viejo city, California', '9': 'Alturas city, California', '10': 'Amador City city, California', '11': 'American Canyon city, California', '12': 'Anaheim city, California', '13': 'Anderson city, California', '14': 'Angels city, California', '15': 'Antioch city, California', '16': 'Apple Valley town, California', '17': 'Arcadia city, California', '18': 'Arcata city, California', '19': 'Arroyo Grande city, California', '20': 'Artesia city, California', '21': 'Arvin city, California', '22': 'Atascadero city, California', '23': 'Atherton town, California', '24': 'Atwater city, California', '25': 'Auburn city, California', '26': 'Avalon city, California', 
# ...

# %%
ca_data['1-APR-2010'] = ca_data.pop('Unnamed: 1')

# %%
ca_data['Estimates'] = ca_data.pop('Unnamed: 2')

# %%
ca_data['2010'] = ca_data.pop('Unnamed: 3')

# %%
ca_data['2011'] = ca_data.pop('Unnamed: 4')

# %%
ca_data['2012'] = ca_data.pop('Unnamed: 5')

# %%
ca_data['2013'] = ca_data.pop('Unnamed: 6')

# %%
ca_data['2014'] = ca_data.pop('Unnamed: 7')

# %%
ca_data['2015'] = ca_data.pop('Unnamed: 8')

# %%
ca_data['2016'] = ca_data.pop('Unnamed: 9')

# %%
ca_data['2017'] = ca_data.pop('Unnamed: 10')

# %%
ca_data['2018'] = ca_data.pop('Unnamed: 11')

# %%
ca_data['2019'] = ca_data.pop('Unnamed: 12')

# %%
print(ca_data)
# Out:
# {'Cities': {'0': 'Annual Estimates of the Resident Population for Incorporated Places in California: April 1, 2010 to July 1, 2019', '1': 'Geographic Area', '2': None, '3': 'Adelanto city, California', '4': 'Agoura Hills city, California', '5': 'Alameda city, California', '6': 'Albany city, California', '7': 'Alhambra city, California', '8': 'Aliso Viejo city, California', '9': 'Alturas city, California', '10': 'Amador City city, California', '11': 'American Canyon city, California', '12': 'Anaheim city, California', '13': 'Anderson city, California', '14': 'Angels city, California', '15': 'Antioch city, California', '16': 'Apple Valley town, California', '17': 'Arcadia city, California', '18': 'Arcata city, California', '19': 'Arroyo Grande city, California', '20': 'Artesia city, California', '21': 'Arvin city, California', '22': 'Atascadero city, California', '23': 'Atherton town, California', '24': 'Atwater city, California', '25': 'Auburn city, California', '26': 'Avalon city, Ca
# ...

# %%
# Get rid of null and unneeded texts
for subdict in ca_data:
    del ca_data[subdict]['0']
    del ca_data[subdict]['1']
    del ca_data[subdict]['2']
print(ca_data)
# Out:
# {'Cities': {'3': 'Adelanto city, California', '4': 'Agoura Hills city, California', '5': 'Alameda city, California', '6': 'Albany city, California', '7': 'Alhambra city, California', '8': 'Aliso Viejo city, California', '9': 'Alturas city, California', '10': 'Amador City city, California', '11': 'American Canyon city, California', '12': 'Anaheim city, California', '13': 'Anderson city, California', '14': 'Angels city, California', '15': 'Antioch city, California', '16': 'Apple Valley town, California', '17': 'Arcadia city, California', '18': 'Arcata city, California', '19': 'Arroyo Grande city, California', '20': 'Artesia city, California', '21': 'Arvin city, California', '22': 'Atascadero city, California', '23': 'Atherton town, California', '24': 'Atwater city, California', '25': 'Auburn city, California', '26': 'Avalon city, California', '27': 'Avenal city, California', '28': 'Azusa city, California', '29': 'Bakersfield city, California', '30': 'Baldwin Park city, California', '31
# ...

# %%
for subdict in ca_data:
    del ca_data[subdict]['485']
    del ca_data[subdict]['486']
    del ca_data[subdict]['487']
    del ca_data[subdict]['488']
    del ca_data[subdict]['489']
print(ca_data)
# Out:
# {'Cities': {'3': 'Adelanto city, California', '4': 'Agoura Hills city, California', '5': 'Alameda city, California', '6': 'Albany city, California', '7': 'Alhambra city, California', '8': 'Aliso Viejo city, California', '9': 'Alturas city, California', '10': 'Amador City city, California', '11': 'American Canyon city, California', '12': 'Anaheim city, California', '13': 'Anderson city, California', '14': 'Angels city, California', '15': 'Antioch city, California', '16': 'Apple Valley town, California', '17': 'Arcadia city, California', '18': 'Arcata city, California', '19': 'Arroyo Grande city, California', '20': 'Artesia city, California', '21': 'Arvin city, California', '22': 'Atascadero city, California', '23': 'Atherton town, California', '24': 'Atwater city, California', '25': 'Auburn city, California', '26': 'Avalon city, California', '27': 'Avenal city, California', '28': 'Azusa city, California', '29': 'Bakersfield city, California', '30': 'Baldwin Park city, California', '31
# ...

# %%
# Sort the dict into ascending order and find the current 10 highest and 10 lowest populated cities 
print(ca_data['2019'])
# Out:
# {'3': '34,049', '4': '20,222', '5': '77,624', '6': '19,696', '7': '83,750', '8': '50,887', '9': '2,563', '10': '190', '11': '20,475', '12': '350,365', '13': '10,630', '14': '3,956', '15': '111,502', '16': '73,453', '17': '57,939', '18': '18,431', '19': '17,976', '20': '16,601', '21': '21,851', '22': '30,075', '23': '7,137', '24': '29,559', '25': '14,195', '26': '3,681', '27': '13,496', '28': '49,974', '29': '384,145', '30': '75,251', '31': '31,221', '32': '23,915', '33': '51,063', '34': '35,521', '35': '76,435', '36': '42,012', '37': '26,941', '38': '2,104', '39': '28,240', '40': '121,363', '41': '33,792', '42': '5,279', '43': '1,879', '44': '3,747', '45': '1,245', '46': '19,682', '47': '1,070', '48': '26,227', '49': '43,255', '50': '64,474', '51': '4,671', '52': '5,102', '53': '81,788', '54': '102,511', '55': '30,889', '56': '23,853', '57': '39,825', '58': '14,198', '59': '9,160', '60': '7,114', '61': '5,247', '62': '69,888', '63': '41,793', '64': '11,280', '65': '10,010', '66': '11
# ...

# %%
type(ca_data['2019'])
# Out:
# dict

# %%
current_pop = ca_data['2019']
print(current_pop)
# Out:
# {'3': '34,049', '4': '20,222', '5': '77,624', '6': '19,696', '7': '83,750', '8': '50,887', '9': '2,563', '10': '190', '11': '20,475', '12': '350,365', '13': '10,630', '14': '3,956', '15': '111,502', '16': '73,453', '17': '57,939', '18': '18,431', '19': '17,976', '20': '16,601', '21': '21,851', '22': '30,075', '23': '7,137', '24': '29,559', '25': '14,195', '26': '3,681', '27': '13,496', '28': '49,974', '29': '384,145', '30': '75,251', '31': '31,221', '32': '23,915', '33': '51,063', '34': '35,521', '35': '76,435', '36': '42,012', '37': '26,941', '38': '2,104', '39': '28,240', '40': '121,363', '41': '33,792', '42': '5,279', '43': '1,879', '44': '3,747', '45': '1,245', '46': '19,682', '47': '1,070', '48': '26,227', '49': '43,255', '50': '64,474', '51': '4,671', '52': '5,102', '53': '81,788', '54': '102,511', '55': '30,889', '56': '23,853', '57': '39,825', '58': '14,198', '59': '9,160', '60': '7,114', '61': '5,247', '62': '69,888', '63': '41,793', '64': '11,280', '65': '10,010', '66': '11
# ...

# %%
type(current_pop)
# Out:
# dict

# %%
if value in current_pop != str:
    print(value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9970eaa2cd6c> in <module>
# ----> 1 if value in current_pop != str:
#       2     print(value)
#
# NameError: name 'value' is not defined
